# %%
import pandas as pd
import numpy as np

# %%
fitbit = pd.read_csv('steps_df.csv')
apple = pd.read_csv('total_steps.csv')

# %%
fitbit.rename({'value':'Fitbit_Steps'},axis=1, inplace=True)

# %%
apple.rename({'value':'Apple_Steps'},axis=1, inplace=True)

# %%
fitbit[fitbit.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [dateTime, Fitbit_Steps]
# Index: []

# %%
apple[apple.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [dateTime, Apple_Steps]
# Index: []

# %%
combined = fitbit.merge(apple,how='left',on='dateTime')

# %%
combined['steps']=np.where(combined['Fitbit_Steps'] == 0, combined['Apple_Steps'], combined['Fitbit_Steps'])

# %%
combined
# Out:
#         dateTime  Fitbit_Steps  Apple_Steps    steps
# 0     2019-06-01             0      10349.0  10349.0
# 1     2019-06-02             0       6527.0   6527.0
# 2     2019-06-03             0       8023.0   8023.0
# 3     2019-06-04             0       7517.0   7517.0
# 4     2019-06-05             0       9608.0   9608.0
# ...          ...           ...          ...      ...
# 1730  2024-02-25             0       3016.0   3016.0
# 1731  2024-02-26             0       2837.0   2837.0
# 1732  2024-02-27             0       2468.0   2468.0
# 1733  2024-02-28             0       5714.0   5714.0
# 1734  2024-02-29             0      10302.0  10302.0
#
# [1735 rows x 4 columns]

# %%
import plotly.express as px

# %%
fig = px.line(combined, x='dateTime', y='steps', title='Time Series Plot')
# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
